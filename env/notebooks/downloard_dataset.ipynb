# %%
import numpy as np

# %%
{
  "username": "dineshpiyasamara",
  "key": "KGAT_694a00e07a054ca7f54ddafaa6dc0948"
}
# Out:
# {'username': 'dineshpiyasamara',
#  'key': 'KGAT_694a00e07a054ca7f54ddafaa6dc0948'}

# %%
import os
os.environ["KAGGLE_API_TOKEN"] = "KGAT_694a00e07a054ca7f54ddafaa6dc0948"

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
# !/usr/local/bin/python3 -m pip install kaggle
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /usr/local/bin/python3 -m pip install --upgrade pip

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 3
#       1 import kaggle
# ----> 3 path = kaggle.dataset_download("dineshpiyasamara/sentiment-analysis-dataset")
#       5 print("Path to dataset files:", env/artifacts)
#
# AttributeError: module 'kaggle' has no attribute 'dataset_download'
